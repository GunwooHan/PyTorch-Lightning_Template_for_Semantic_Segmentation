# %%
import os
import sys
import inspect
sys.path.append(os.path.join('/home/aieson/codes/PyTorch-Lightning_Template_for_Semantic_Segmentation/trains/resnest50d_ada', '../../'))
sys.path.append(os.path.join('/home/aieson/codes/PyTorch-Lightning_Template_for_Semantic_Segmentation/trains/resnest50d_ada', '../'))


import glob
import argparse

import torch
import torch.nn as nn
import numpy as np
import pytorch_lightning as pl
import wandb
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold

from datasets import SegmentationDataset
from transforms import make_transform
from models.unet_inferface import UnetModel
from utils import train_test_split
import cv2
import config as cfg
import torch.nn.functional as F
import ttach as tta
# import autocast
from torch.cuda.amp import autocast

print(cfg.MODEL_INTERFACE())
# Out:
# Added new Model:	timm-resnest14d-ada
# Added new Model:	timm-resnest26d-ada
# Added new Model:	timm-resnest50d-ada
# Added new Model:	timm-resnest101e-ada
# Added new Model:	timm-resnest200e-ada
# Added new Model:	timm-resnest269e-ada
# Added new Model:	timm-resnest50d_4s2x40d-ada
# Added new Model:	timm-resnest50d_1s4x24d-ada
# Identity()
# AvgPool2d(kernel_size=2, stride=2, padding=0)
# AvgPool2d(kernel_size=2, stride=2, padding=0)
# AvgPool2d(kernel_size=2, stride=2, padding=0)
# ResNeStAdaUnetPPModel(
#   (model): UnetPlusPlus(
#     (encoder): ResNestEncoderAdaPool(
#       (conv1): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
model = cfg.MODEL_INTERFACE()
# Out:
# Identity()
# AvgPool2d(kernel_size=2, stride=2, padding=0)
# AvgPool2d(kernel_size=2, stride=2, padding=0)
# AvgPool2d(kernel_size=2, stride=2, padding=0)

# %%
model_pth = torch.load('/home/aieson/codes/PyTorch-Lightning_Template_for_Semantic_Segmentation/trains/resnest50d_ada/checkpoints/resnest50d_adaupp_fold05_val/jac_idx=0.9049-v1.ckpt')

# %%
model_pth = torch.load('/home/aieson/codes/PyTorch-Lightning_Template_for_Semantic_Segmentation/trains/resnest50d_ada/checkpoints/resnest50d_adaupp_fold05_val/jac_idx=0.9049-v1.ckpt')
missing_keys = ["model.encoder.maxpool.beta", "model.encoder.layer2.0.avd_last.beta", "model.encoder.layer2.0.downsample.0.beta", "model.encoder.layer3.0.avd_last.beta", "model.encoder.layer3.0.downsample.0.beta", "model.encoder.layer4.0.avd_last.beta", "model.encoder.layer4.0.downsample.0.beta"]
for m_key in missing_keys:
    model_pth['state_dict'][m_key] = torch.ones((1,1)).to('cuda')

# %%
# save model
torch.save(model_pth, '/home/aieson/codes/PyTorch-Lightning_Template_for_Semantic_Segmentation/trains/resnest50d_ada/checkpoints/resnest50d_adaupp_fold05_val/jac_idx=0.9049-v1_fix.ckpt')

# %%
missing_keys = ["model.encoder.maxpool.beta", "model.encoder.layer2.0.avd_last.beta", "model.encoder.layer2.0.downsample.0.beta", "model.encoder.layer3.0.avd_last.beta", "model.encoder.layer3.0.downsample.0.beta", "model.encoder.layer4.0.avd_last.beta", "model.encoder.layer4.0.downsample.0.beta"]
for m_key in missing_keys:
    print(model_pth['state_dict'][m_key].shape)
# Out:
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])

# %%
torch.ones((2))
# Out:
# tensor([1., 1.])
